# %% [markdown]
# # OK so first thought is that the seed messed stuff up!
#
# so gotta try again with --random_seed == 0 and see if that makes a difference?
#
# While its running, set up all eval code. also look into the code itself for bugs

# %%
from utils import vis, data_funcs
import pandas as pd

# %% [markdown]
# # 1. Is the tenth still good as before after regeneration?
#
# Have retraining with tenth for indices 0-20
#
# Get QQ plots then I think

# %%
data = data_funcs.getQQplotData(f1='retr_div10', idx_range=20, retrained=True)
cfgs = vis.getConfigs(size=10, qq=True)

vis.graph('qq', data, cfgs)

# %%
for i in range(10):
    data = data_funcs.loadPreds('div10', i)
    info = data_funcs.getBasicDistrInfo(data)
    print(info['median'])
# Out:
# 2681.4588794724805
# -1.9467874670898132e-07
# 3.682778632354679
# -0.6297334369577425
# 4.002645458266722
# -1.8548114749524671
# -0.02526051236211672
# -0.9624011490581985
# 0.01165790488626354
# -0.00046280451049637926

# %%
data = data_funcs.loadPreds('tenth-0', 12)
info = data_funcs.getBasicDistrInfo(data)

for i in info:
    print(i, info[i])
# Out:
# max 0.7735741518021473
# min -0.9928430445869638
# mean -0.00048209162034557046
# median 5.263620983059477e-05
# std 0.05571970524390045

# %% [markdown]
# # 1b. Does different random seeds affect?
#
# Yes

# %%
f1 = 'tenth-3'
f2 = 'tenth-9'


cors, ps = data_funcs.correlateTwoFoldersExtreme(f1, f2)
vis.graph('hist', cors)

# %%
dfs = []

for seed in [0, 3, 9]:
    folder = 'tenth-%s' % seed
    all_medians = []
    for idx in range(5):
        infs = data_funcs.loadPreds(folder, idx)
        info = data_funcs.getBasicDistrInfo(infs)
        
        all_medians.append({'median inf': info['median'], 'seed': seed, 'test idx': idx})
        
    dfs.append(pd.DataFrame(all_medians))
    
df = pd.concat(dfs)

# %%
data_funcs.getBasicDistrInfo(df['median inf'].values)
# Out:
# {'max': 21387541.71276234,
#  'min': -466.82966822827404,
#  'mean': 1426487.3691551178,
#  'median': -2.0685540200343198e-07,
#  'std': 5522059.994301768}

# %%
df
# Out:
#      median inf  seed  test idx
# 0 -3.357971e-07     0         0
# 1 -2.068554e-07     0         1
# 2 -6.558587e-07     0         2
# 3 -6.852807e-07     0         3
# 4 -6.733611e-07     0         4
# 0 -8.852059e-04     3         0
# 1 -4.922734e-06     3         1
# 2  4.906076e+00     3         2
# 3 -1.666969e-07     3         3
# 4  2.024836e-01     3         4
# 0 -4.668297e+02     9         0
# 1  9.601513e-02     9         1
# 2  2.138754e+07     9         2
# 3  1.022798e+04     9         3
# 4  2.467880e+00     9         4

# %%
cfgs = vis.getConfigs()
cfgs['x'] = 'test idx'
cfgs['y'] = 'median inf'
cfgs['hue'] = 'seed'
cfgs['title'] = 0

vis.graph('bar-hue', dfs[0], cfgs)

# %%
cfgs['title'] = 3
vis.graph('bar-hue', dfs[1], cfgs)

# %%
cfgs['title'] = 9
vis.graph('bar-hue', dfs[2], cfgs)

# %% [markdown]
# ### oy ok so hard to graph because a bajillion diff scales

# %%
all_medians = []
for idx in range(50):
    infs = data_funcs.loadPreds('div10', idx)
    info = data_funcs.getBasicDistrInfo(infs)

    all_medians.append(info['median'])

dfs.append(pd.DataFrame(all_medians))

# %%
vis.graph('hist', all_medians)

# %% [markdown]
# # What if no random seed?

# %% [markdown]
# # 2. Is full vs one still bad after regeneration?

# %% [markdown]
# # 3. How does it change with different divisors?
